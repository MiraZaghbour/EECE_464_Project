# %% [markdown]
# <h1>PROJECT 464</h1>

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h1>Dataset 1</h1>

# %%
#SpreadSheet Datafile name
file = 'Datasets.xlsx'

#Load spreadsheet
data = pd.read_excel(file)

#Load Dataset 1 into DataFrame
ds1 = pd.read_excel(file, sheet_names = 'Dataset 1', index_col=0)

# %% [markdown]
# <h2>Filling missing values and Normalization</h2>

# %%
ds1.fillna(ds1.median(), inplace=True)
min_max_scaler = preprocessing.MinMaxScaler()
ds1[ds1.columns[5:90]] = min_max_scaler.fit_transform(ds1[ds1.columns[5:90]])
ds1_normalized = pd.DataFrame(ds1)
ds1_normalized.head()
# Out:
#          Team  League/Division  Season  Head Coach  Manager         A  \
# Athlete
# 1          36              5.0       1           7     13.0  0.894737
# 2          50              5.0       1           7     13.0  1.000000
# 3          41              5.0       1           7     13.0  0.894737
# 4          60              1.0       1          10     29.0  0.947368
# 5          22              1.0       1          10     29.0  0.947368
#
#                AA     AB         B        BA    ...       WW        WX  \
# Athlete                                         ...
# 1        0.857143  0.875  0.584098  0.582996    ...     0.95  0.827586
# 2        0.914286  1.000  0.576394  0.582996    ...     0.95  0.620690
# 3        0.714286  0.750  0.564839  0.582996    ...     0.95  0.758621
# 4        0.571429  0.875  0.706530  0.757085    ...     0.95  0.655172
# 5        0.857143  0.750  0.668012  0.757085    ...     0.95  0.137931
#
# ...

# %% [markdown]
# <h1>PLOTS</h1>

# %% [markdown]
# <h2>OO wrt HeadCoach</h2>

# %%
#OO wrt HeadCoach
sns.jointplot(x='Head Coach', y='OO', data=ds1, kind='reg', dropna=True)

# %%
plt.figure(figsize=(15,5))
sns.violinplot(x='Head Coach', y='OO', data=ds1, inner=None)

# %% [markdown]
# <h2> S wrt Manager and Season </h2>

# %%
sns.jointplot(x='Manager', y='S', data=ds1, kind='reg', dropna=True)

# %%
plt.figure(figsize=(15,8))
sns.violinplot(x='Manager', y='S', data=ds1)

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.violinplot(x='Manager', y='S', data=ds1[ds1.Season==1], inner=None)
plt.subplot(2,2,2)
sns.violinplot(x='Manager', y='S', data=ds1[ds1.Season==2], inner=None)
plt.subplot(2,2,3)
sns.violinplot(x='Manager', y='S', data=ds1[ds1.Season==3], inner=None)
plt.subplot(2,2,4)
sns.violinplot(x='Manager', y='S', data=ds1[ds1.Season==4], inner=None)

# %%
# S wrt Season
plt.figure(figsize=(7,7))
sns.violinplot(x='Season', y='S', data=ds1)

# %% [markdown]
# <h2>R wrt HeadCoach and Season</h2>

# %%
sns.jointplot(x='Head Coach', y='R', data=ds1, kind='reg', color='g')

# %%
plt.figure(figsize=(15,8))
sns.violinplot(x='Head Coach', y='R', data=ds2, width=2)

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.violinplot(x='Head Coach', y='R', data=ds2[ds2.Season==1], inner=None, width=2)
plt.subplot(2,2,2)
sns.violinplot(x='Head Coach', y='R', data=ds2[ds2.Season==2], inner=None, width=2)
plt.subplot(2,2,3)
sns.violinplot(x='Head Coach', y='R', data=ds2[ds2.Season==3], inner=None, width=2)
plt.subplot(2,2,4)
sns.violinplot(x='Head Coach', y='R', data=ds2[ds2.Season==4], inner=None, width=2)

# %%
plt.figure(figsize=(7,7))
sns.violinplot(x='Season', y='R', data=ds1)

# %% [markdown]
# <h2>NN wrt OO and Season</h2>

# %%
# NN wrt OO and Season
sns.jointplot(x='OO', y='NN', data=ds1, color='g', kind='reg')
sns.jointplot(x='OO', y='NN', data=ds1[ds1.Season==1], color='b', kind='reg')
sns.jointplot(x='OO', y='NN', data=ds1[ds1.Season==2], color='c', kind='reg')
sns.jointplot(x='OO', y='NN', data=ds1[ds1.Season==3], color='m', kind='reg')
sns.jointplot(x='OO', y='NN', data=ds1[ds1.Season==4], color='r', kind='reg')

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.violinplot(x='NN', y='OO', data=ds1[ds1.Season==1], inner=None)
plt.subplot(2,2,2)
sns.violinplot(x='NN', y='OO', data=ds1[ds1.Season==2], inner=None)
plt.subplot(2,2,3)
sns.violinplot(x='NN', y='OO', data=ds1[ds1.Season==3], inner=None)
plt.subplot(2,2,4)
sns.violinplot(x='NN', y='OO', data=ds1[ds1.Season==4], inner=None)

# %%
#NN wrt Season
plt.figure(figsize=(7,7))
sns.violinplot(x='Season', y='NN', data=ds1)

# %% [markdown]
# <h2>OO wrt JI and Season</h2>

# %%
# OO wrt JI and Season
sns.jointplot(x='JI', y='OO', data=ds1, color='g', kind='reg')
sns.jointplot(x='JI', y='OO', data=ds1[ds1.Season==1], color='b', kind='reg')

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.violinplot(x='JI', y='OO', data=ds1[ds1.Season==1], inner=None)
plt.subplot(2,2,2)
sns.violinplot(x='JI', y='OO', data=ds1[ds1.Season==2], inner=None)
plt.subplot(2,2,3)
sns.violinplot(x='JI', y='OO', data=ds1[ds1.Season==3], inner=None)
plt.subplot(2,2,4)
sns.violinplot(x='JI', y='OO', data=ds1[ds1.Season==4], inner=None)

# %%
# OO wrt Season
plt.figure(figsize=(7,7))
sns.violinplot(x='Season', y='OO', data=ds1)

# %% [markdown]
# <h2>HG wrt Y and Season</h2>

# %%
# HG wrt Y and Season
sns.jointplot(x='Y', y='HG', data=ds1, color='g', kind='reg')
sns.jointplot(x='Y', y='HG', data=ds1[ds1.Season==1], color='b', kind='reg')
sns.jointplot(x='Y', y='HG', data=ds1[ds1.Season==2], color='c', kind='reg')
sns.jointplot(x='Y', y='HG', data=ds1[ds1.Season==3], color='m', kind='reg')
sns.jointplot(x='Y', y='HG', data=ds1[ds1.Season==4], color='r', kind='reg')

# %%
# HG wrt Season
plt.figure(figsize=(7,7))
sns.violinplot(x='Season', y='HG', data=ds1)

# %% [markdown]
# <h2>B wrt League/Division and Season</h2>

# %%
#B wrt League/Division and Season
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
sns.violinplot(data=ds1[ds1.Season==1], x='League/Division', y='B', ax=ax1, color='g')
sns.violinplot(data=ds1[ds1.Season==2], x='League/Division', y='B', ax=ax2, color='b')
sns.violinplot(data=ds1[ds1.Season==3], x='League/Division', y='B', ax=ax3, color='r')
sns.violinplot(data=ds1[ds1.Season==4], x='League/Division', y='B', ax=ax4, color='c')

# %%
sns.violinplot(x='League/Division', y='B', data=ds1)

# %%
# Useless
sns.jointplot(x='League/Division', y='B', data=ds1, color='g', kind='reg')
sns.jointplot(x='League/Division', y='B', data=ds1[ds1.Season==1], color='b', kind='reg')
sns.jointplot(x='League/Division', y='B', data=ds1[ds1.Season==2], color='c', kind='reg')
sns.jointplot(x='League/Division', y='B', data=ds1[ds1.Season==3], color='m', kind='reg')
sns.jointplot(x='League/Division', y='B', data=ds1[ds1.Season==4], color='r', kind='reg')

# %%
# B wrt Season
plt.figure(figsize=(7,7))
sns.violinplot(x='Season', y='B', data=ds1)

# %% [markdown]
# <h1>Prediction</h1>

# %%
from sklearn import model_selection
from sklearn.model_selection import cross_val_score,train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error

from sklearn import linear_model
from sklearn.svm import SVR

# %%
#Different regressor instances
regressors = [
    linear_model.LinearRegression(),
    linear_model.HuberRegressor(),
    linear_model.BayesianRidge(normalize=True),
    linear_model.Lasso(alpha=1e-4),
    linear_model.LassoLarsIC(),
    linear_model.Ridge(),
    SVR(kernel='linear'),
]

# %%
# Method 1
def predictor1(regressors, X, y):
    cv_split = model_selection.ShuffleSplit(n_splits=10, test_size=0.25, train_size=0.75, random_state=42)
    results1 = pd.DataFrame(columns=['Name', 'Train Score', 'Test Score'])
    index = 0
    for reg in regressors:
        cv_results1 = model_selection.cross_validate(reg, X, y, cv = cv_split)
        results1.loc[index, 'Name'] = reg.__class__.__name__
        results1.loc[index, 'Train Score'] = cv_results['train_score'].mean()
        results1.loc[index, 'Test Score'] = cv_results['test_score'].mean()
        index = index + 1
    return results1

# %%
# Method 2
def predictor2(regressors, X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)
    results2 = pd.DataFrame(columns=['Name', 'Train Score', 'Test Score', 'RMSE'])
    index2 = 0

    for reg in regressors:
        reg.fit(X_train,y_train)
        y_pred = reg.predict(X_test)

        #Filling panda DataFrame table of results
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        results2.loc[index2, 'Name'] = reg.__class__.__name__
        results2.loc[index2, 'Train Score'] = reg.score(X_train, y_train)
        results2.loc[index2, 'Test Score'] = reg.score(X_test, y_test)
        results2.loc[index2, 'RMSE'] = rmse

        index2 = index2 + 1
    return results2

# %% [markdown]
# <h2>Predict feature “R” given “Head coach”, “B”, “S”, “HG”, “HH”, and “OO”</h2>

# %%
X1 = ds1[['B','S','HG','HH','OO']]
y1 = ds1['R']

table11 = predictor1(regressors, X1, y1)
table21 = predictor2(regressors, X1, y1)

# %%
table11
# Out:
#                Name Train Score Test Score
# 0  LinearRegression    0.698617   0.696525
# 1    HuberRegressor    0.698617   0.696525
# 2     BayesianRidge    0.698617   0.696525
# 3             Lasso    0.698617   0.696525
# 4       LassoLarsIC    0.698617   0.696525
# 5             Ridge    0.698617   0.696525
# 6               SVR    0.698617   0.696525

# %%
table21
# Out:
#                Name Train Score Test Score       RMSE
# 0  LinearRegression     0.68844   0.731228  0.0882297
# 1    HuberRegressor    0.685415   0.731403  0.0882011
# 2     BayesianRidge    0.688419   0.730626  0.0883284
# 3             Lasso    0.688295   0.731069  0.0882559
# 4       LassoLarsIC    0.686361   0.725775  0.0891203
# 5             Ridge     0.68489   0.718469  0.0902997
# 6               SVR    0.683753   0.722253  0.0896907

# %% [markdown]
# <h2>Predict feature “OO” given “Head coach”, “C”, “JI”, and “NN”</h2>

# %%
X2 = ds1[['Head Coach','C','JI','NN']]
y2 = ds1['OO']

table12 = predictor1(regressors, X2, y2)
table22 = predictor2(regressors, X2, y2)

# %%
table12
# Out:
#                Name Train Score Test Score
# 0  LinearRegression    0.698617   0.696525
# 1    HuberRegressor    0.698617   0.696525
# 2     BayesianRidge    0.698617   0.696525
# 3             Lasso    0.698617   0.696525
# 4       LassoLarsIC    0.698617   0.696525
# 5             Ridge    0.698617   0.696525
# 6               SVR    0.698617   0.696525

# %%
table22
# Out:
#                Name Train Score Test Score      RMSE
# 0  LinearRegression    0.140084    0.24121  0.115756
# 1    HuberRegressor    0.110662   0.171137  0.120983
# 2     BayesianRidge    0.139606   0.234446  0.116271
# 3             Lasso    0.139998   0.238237  0.115982
# 4       LassoLarsIC    0.138758   0.233869  0.116314
# 5             Ridge    0.136923   0.220812  0.117301
# 6               SVR    0.134777   0.217292  0.117566

# %% [markdown]
# <h2>Predict feature “Y” given “C”, “HG”, and “NN”</h2>

# %%
X3 = ds1[['C','HG','NN']]
y3 = ds1['Y']

table13 = predictor1(regressors, X3, y3)
table23 = predictor2(regressors, X3, y3)

# %%
table13
# Out:
#                Name Train Score Test Score
# 0  LinearRegression    0.698617   0.696525
# 1    HuberRegressor    0.698617   0.696525
# 2     BayesianRidge    0.698617   0.696525
# 3             Lasso    0.698617   0.696525
# 4       LassoLarsIC    0.698617   0.696525
# 5             Ridge    0.698617   0.696525
# 6               SVR    0.698617   0.696525

# %%
table23
# Out:
#                Name Train Score   Test Score      RMSE
# 0  LinearRegression   0.0503636    0.0247988  0.186561
# 1    HuberRegressor   0.0415583   0.00205637  0.188724
# 2     BayesianRidge   0.0494513    0.0252223  0.186521
# 3             Lasso   0.0503276    0.0251904  0.186524
# 4       LassoLarsIC   0.0503636    0.0247988  0.186561
# 5             Ridge   0.0501295    0.0259255  0.186453
# 6               SVR   0.0385937  0.000597735  0.188862

# %% [markdown]
# <h1>Dataset 2</h1>

# %%
#Load Dataset 2 into DataFrame
ds2 = pd.read_excel(file, sheet_names = 'Dataset 2', index_col=0)

# %% [markdown]
# <h2>Filling missing values and Normalization</h2>

# %%
ds2.fillna(ds2.median(), inplace=True)
min_max_scaler = preprocessing.MinMaxScaler()
ds2[ds2.columns[5:90]] = min_max_scaler.fit_transform(ds2[ds2.columns[5:90]])
ds2_normalized = pd.DataFrame(ds2)
ds2_normalized.head()
# Out:
#          Team  League/Division  Season  Head Coach  Manager         A  \
# Athlete
# 1          36              5.0       1           7     13.0  0.894737
# 2          50              5.0       1           7     13.0  1.000000
# 3          41              5.0       1           7     13.0  0.894737
# 4          60              1.0       1          10     29.0  0.947368
# 5          22              1.0       1          10     29.0  0.947368
#
#                AA     AB         B        BA    ...       WW        WX  \
# Athlete                                         ...
# 1        0.857143  0.875  0.584098  0.582996    ...     0.95  0.827586
# 2        0.914286  1.000  0.576394  0.582996    ...     0.95  0.620690
# 3        0.714286  0.750  0.564839  0.582996    ...     0.95  0.758621
# 4        0.571429  0.875  0.706530  0.757085    ...     0.95  0.655172
# 5        0.857143  0.750  0.668012  0.757085    ...     0.95  0.137931
#
# ...

# %% [markdown]
# <h1>Plots</h1>

# %% [markdown]
# <h2>Plot feature “LM” with respect to “Head coach”</h2>

# %%
plt.figure(figsize=(15,5))
sns.violinplot(data=ds2, x='Head Coach', y='LM')

# %% [markdown]
# <h2>Plot feature “PQ” with respect to “Manager” and “Season”</h2>

# %%
plt.figure(figsize=(15,5))
sns.violinplot(data=ds2, x='Manager', y='PQ', width=1.1)

# %%
#If you want boxplots to show, remove inner=None
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.violinplot(x='Manager', y='PQ', data=ds2[ds2.Season==1], inner=None)
plt.subplot(2,2,2)
sns.violinplot(x='Manager', y='PQ', data=ds2[ds2.Season==2], inner=None)
plt.subplot(2,2,3)
sns.violinplot(x='Manager', y='PQ', data=ds2[ds2.Season==3], inner=None)
plt.subplot(2,2,4)
sns.violinplot(x='Manager', y='PQ', data=ds2[ds2.Season==4], inner=None)

# %%
sns.violinplot(x='Season', y='PQ', data=ds2)

# %% [markdown]
# <h2>Plot feature “OO” with respect to “Head coach” and “Season”</h2>

# %%
plt.figure(figsize=(15,5))
sns.violinplot(data=ds2, x='Head Coach', y='OO', width=1.5)

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.violinplot(x='Head Coach', y='OO', data=ds2[ds2.Season==1], inner=None)
plt.subplot(2,2,2)
sns.violinplot(x='Head Coach', y='OO', data=ds2[ds2.Season==2], inner=None)
plt.subplot(2,2,3)
sns.violinplot(x='Head Coach', y='OO', data=ds2[ds2.Season==3], inner=None)
plt.subplot(2,2,4)
sns.violinplot(x='Head Coach', y='OO', data=ds2[ds2.Season==4], inner=None)
#what's with the horizontal lines?

# %% [markdown]
# <h2>Plot feature “BC” with respect to “LM” and “Season”</h2>

# %%
sns.jointplot(data=ds2, x='LM', y='BC', kind='reg')

# %%
sns.jointplot(x='LM', y='BC', data=ds2[ds2.Season==1], color='b', kind='reg')
sns.jointplot(x='LM', y='BC', data=ds2[ds2.Season==2], color='c', kind='reg')
sns.jointplot(x='LM', y='BC', data=ds2[ds2.Season==3], color='m', kind='reg')
sns.jointplot(x='LM', y='BC', data=ds2[ds2.Season==4], color='r', kind='reg')

# %%
plt.figure(figsize=(15,5))
sns.violinplot(data=ds2, x='LM', y='BC')

# %%
sns.violinplot(data=ds2, x='Season', y='LM')

# %% [markdown]
# <h2>Plot feature “LM” with respect to “HH” and “Season”</h2>

# %%
sns.jointplot(data=ds2, x='HH', y='LM', kind='reg')

# %%
sns.jointplot(x='LM', y='HH', data=ds2[ds2.Season==1], color='b', kind='reg')
sns.jointplot(x='LM', y='HH', data=ds2[ds2.Season==2], color='c', kind='reg')
sns.jointplot(x='LM', y='HH', data=ds2[ds2.Season==3], color='m', kind='reg')
sns.jointplot(x='LM', y='HH', data=ds2[ds2.Season==4], color='r', kind='reg')

# %%
# Or a boxplot could work
sns.violinplot(data=ds2, x='Season', y='HH')

# %%
#Useless
plt.figure(figsize=(15,5))
sns.violinplot(data=ds2, x='LM', y='HH')

# %% [markdown]
# <h2>Plot feature “EF” with respect to “League/Division” and “Season” for the data instances without missing values in the “League/Division” feature</h2>

# %%
plt.figure(figsize=(10,5))
sns.stripplot(data=ds2, x='League/Division', y='EF', color='b')

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.stripplot(data=ds2[ds2.Season==1], x='League/Division', y='EF', color='m')
plt.subplot(2,2,2)
sns.stripplot(data=ds2[ds2.Season==2], x='League/Division', y='EF', color='c')
plt.subplot(2,2,3)
sns.stripplot(data=ds2[ds2.Season==3], x='League/Division', y='EF', color='r')
plt.subplot(2,2,4)
sns.stripplot(data=ds2[ds2.Season==4], x='League/Division', y='EF', color='g')
